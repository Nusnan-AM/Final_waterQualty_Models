# %% [markdown]
# <a href="https://colab.research.google.com/github/Nusnan-AM/Final_waterQualty_Models/blob/main/Final_DecisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  16.pptx
# 'AidePersona (1).xlsx'
# 'AidePersona (2).xlsx'
#  AidePersona.xlsx
# 'App2951 (1).pdf'
#  App2951.pdf
#  App2953.pdf
#  App2954.pdf
# 'Appointment Letter - Internship Tharushi Vithanage.gdoc'
# 'Appointment Letter - Internship Tharushi Vithanage.pdf'
# 'BOCDownload_26_4_20239_9_28 (1).pdf'
#  catboost_info
# 'ceylin (1).gsheet'
# 'ceylin (2).gsheet'
# 'ceylin (3).gsheet'
# 'ceylin (4).gsheet'
#  ceylin.gsheet
#  Ceylin.gsheet
#  ceylin.xlsx
# 'check list for student -.docx'
# 'Colab Notebooks'
#  colour_ngboost_model.pkl
#  colour_ngboost.pkl
# 'Consulting proposal (1).gslides'
# 'Consulting proposal (2).gslides'
# 'Consulting proposal.gslides'
# 'Copy of Swag_bag.xlsx'
# 'Course work - React.gdoc'
# 'C Sharp Programming Advance.zip'
# 'Edited2 Final CST 27 PROPOSAL.docx'
#  Final_colour.csv
#  Final_ec.csv
#  Final_ph.csv
#  Final_tds.csv
#  Final_turbidity.csv
# 'Getting started.pdf'
# 'Group 27Research.drawio.png'
# 'Group_27-Research Proposal new.gdoc'
# 'Hash Casino (1).xlsx'
# 'Hash Casino (2).xlsx'
# 'Hash Casino (3).xlsx'
# 'Hash Casino (4).xlsx'
# 'Hash Casino (5).xlsx'
# 'Hash Casino (6).xlsx'
# 'Hash Casino - Execusion (1).gsheet'
# 'Hash Casino - Execusion (1).xlsx'
# 'Hash Casino - Execusion (2).xlsx'
# 'Hash Casino - Execusion.gsheet'
# 'Hash Casino - Execusion.xlsx'
# 'Hash Casino.xlsx'
#  Hush.gsheet
#  jartest.csv
#  JARTEST.csv
#  laptop
#  Minitab.v17.1.0.Cracked.zip
# 'Model Summary.gsheet'
# 'My Drive'
# 'Noxe SMART SCHOOLS (1).xlsx'
# 'Noxe SMART SCHOOLS(AutoRecovered) (1).xlsx'
# 'Noxe SMART SCHOOLS(AutoRecovered) (2).xlsx'
# 'Noxe SMART SCHOOLS(AutoRecovered).xlsx'
# 'Noxe SMART SCHOOLS.xlsx'
# 'Object Oriented Programming Assignment 01.gdoc'
#  ph_ngboost_model.pkl
#  ph_ngboost.pkl
#  photo_2022-02-18_23-31-40.jpg
# 'Photo album.gslides'
# 'Pitch (1).gslides'
# 'Pitch (2).gslides'
# 'Pitch (3).gslides'
# 'Pitch (4).gslides'
# 'Pitch (5).gslides'
# 'Pitch (6).gslides'
#  Pitch.gslides
# 'PPTX-Genigraphics-Poster-Template-24x36 (1).gslides'
# 'PPTX-Genigraphics-Poster-Template-24x36 (2).gslides'
#  PPTX-Genigraphics-Poster-Template-24x36.gslides
# 'PPTX-Genigraphics-Poster-Template-48x36 (2).gslides'
# 'Prototyping presentation (1).gslides'
# 'Prototyping presentation (2).gslides'
# 'Prototyping presentation.gslides'
#  RAD.drawio
#  radino
# 'Reading(uva google classroom) (1).gdoc'
# 'Reading(uva google classroom) (2).gdoc'
# 'Reading(uva google classroom) (3).gdoc'
# 'Reading(uva google classroom).gdoc'
# 'Research (1).drawio.pdf'
#  Research.drawio.pdf
# 'Sample Letter for Data Collection (1).gdoc'
# 'Screenshot 2024-05-02 211155.png'
#  Swag_bag.xlsx
#  sys.gdoc
# 'Systematic Literature Review.gdoc'
# 'Take Home Assignment 01 - Programming Fundamentals CMJD104.gdoc'
# 'Take Home Assignment 02 - Programming Fundamentals CMJD104.gdoc'
# 'Test Model.gsheet'
# 'Thambii (1).xlsx'
# 'Thambii (2).xlsx'
# 'Thambii (3).xlsx'
# 'Thambii (4).xlsx'
# 'Thambii (5).xlsx'
#  Thambii.xlsx
# 'Tharushi-Vithanage (1).pdf'
#  Tharushi-Vithanage.pdf
#  tharushi.zip
# 'The main purpose of alum (aluminum sulfate) in a water treatment plant is to act as a coagulant.gdoc'
#  turbidity_ngboost_model.pkl
# 'Untitled Diagram'
# 'Untitled Diagram (1).drawio'
# 'Untitled Diagram (1).drawio.png'
# 'Untitled Diagram (2).drawio'
# 'Untitled Diagram.drawio'
# 'Untitled Diagram.drawio.png'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document.gdoc'
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet (10).gsheet'
# 'Untitled spreadsheet (11).gsheet'
# 'Untitled spreadsheet (12).gsheet'
# 'Untitled spreadsheet (13).gsheet'
# 'Untitled spreadsheet (14).gsheet'
# 'Untitled spreadsheet (15).gsheet'
# 'Untitled spreadsheet (16).gsheet'
# 'Untitled spreadsheet (17).gsheet'
# 'Untitled spreadsheet (18).gsheet'
# 'Untitled spreadsheet (19).gsheet'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (20).gsheet'
# 'Untitled spreadsheet (21).gsheet'
# 'Untitled spreadsheet (22).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet (4).gsheet'
# 'Untitled spreadsheet (5).gsheet'
# 'Untitled spreadsheet (6).gsheet'
# 'Untitled spreadsheet (7).gsheet'
# 'Untitled spreadsheet (8).gsheet'
# 'Untitled spreadsheet (9).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'UWUCST20027 A.V.T.DIDULANI.pdf'
#  UWU-CST-20-027.pptx
#  wad

# %%
# %cd /content/gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %% [markdown]
# Load data

# %%
data_PH = pd.read_csv("Final_ph.csv")
data_EC = pd.read_csv("Final_ec.csv")
data_Turbidity = pd.read_csv("Final_turbidity.csv")
data_Colour = pd.read_csv("Final_colour.csv")
data_TDS = pd.read_csv("Final_tds.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_PH.head()
# Out:
#        Date  Raw_Colour  Raw_Turbidity  Raw_Ec  Raw_TDS  Raw_Ph   T1A   T1B  \
# 0  1/1/2019       500.0           74.7   118.4    64.60    7.32  7.08  7.03
# 1  1/2/2019       484.0           46.7   123.8    67.87    8.51  8.84  8.25
# 2  1/3/2019       326.0           42.1   169.5    78.30    7.43  7.67  7.55
# 3  1/7/2019       454.0           43.4   124.5    68.10    7.16  7.04  7.11
# 4  1/8/2019       307.0           38.3   118.4    86.32    7.09  6.91  6.88
#
#     T2A   T2B  ...   F2A   F2B  contact_tank  clear_well  PAC  KMnO4   ACD  \
# 0  7.06  7.09  ...  6.98  6.93          6.83        6.78  2.5   0.52  0.65
# 1  8.37  8.54  ...  7.72  7.74          7.71        7.74  0.5   0.20  0.20
# 2  7.43  7.42  ...  7.65  7.60          7.54        7.61  4.0   0.65  0.30
# 3  7.05  7.10  ...  6.91  6.88          6.89        6.72  1.0   0.18  0.20
# 4  6.86  6.84  ...  6.86  6.85          6.84        6.96  3.0   0.15  0.30
#
#    CalPAC  CalKMnO4  CalACD
# 0   20000      4160    5200
# 1    4000      1600    1600
# 2   32000      5200    2400
# 3    8000      1440    1600
# 4   24000      1200    2400
#
# [5 rows x 26 columns]

# %%
data_EC.head()
# Out:
#          Date  Raw_Colour  Raw_Turbidity  Raw_Ec  Raw_TDS  Raw_Ph    T1A  \
# 0   12/3/2019       500.0           74.7   118.4    64.60    7.32  148.1
# 1   12/4/2019       484.0           46.7   123.8    67.87    8.51  180.6
# 2  11/28/2019       326.0           42.1   169.5    78.30    7.43  180.3
# 3  11/29/2019       454.0           43.4   124.5    68.10    7.16  145.2
# 4  11/26/2019       307.0           38.3   118.4    86.32    7.09  130.3
#
#      T1B    T2A    T2B  ...    F2A    F2B  contact_tank  clear_well  PAC  \
# 0  137.2  144.1  130.1  ...  148.4  149.3         156.5       150.0  2.5
# 1  160.4  169.5  160.7  ...  155.0  157.3         168.4       165.2  0.5
# 2  182.3  180.1  180.2  ...  166.3  166.3         163.6       164.5  4.0
# 3  142.1  141.4  141.3  ...  141.6  141.4         148.7       144.7  1.0
# 4  128.4  126.1  127.3  ...  145.8  152.9         152.7       148.8  3.0
#
#    KMnO4   ACD  CalPAC  CalKMnO4  CalACD
# 0   0.52  0.65   20000      4160    5200
# 1   0.20  0.20    4000      1600    1600
# 2   0.65  0.30   32000      5200    2400
# 3   0.18  0.20    8000      1440    1600
# 4   0.15  0.30   24000      1200    2400
#
# [5 rows x 26 columns]

# %%
data_Turbidity.head()
# Out:
#          Date  Raw_Colour  Raw_Turbidity  Raw_Ec  Raw_TDS  Raw_Ph   T1A   T1B  \
# 0   12/3/2019       500.0           74.7   118.4    64.60    7.32  27.2  16.3
# 1   12/4/2019       484.0           46.7   123.8    67.87    8.51  45.7  28.3
# 2  11/28/2019       326.0           42.1   169.5    78.30    7.43    33  31.2
# 3  11/29/2019       454.0           43.4   124.5    68.10    7.16  18.2  16.2
# 4  11/26/2019       307.0           38.3   118.4    86.32    7.09    38  20.6
#
#     T2A   T2B  ...   F2A   F2B contact_tank clear_well  PAC  KMnO4   ACD  \
# 0  74.9  36.0  ...  0.61  0.63         0.32       0.84  2.5   0.52  0.65
# 1  14.9  15.7  ...  0.40  0.60         0.31       0.42  0.5   0.20  0.20
# 2  32.6  41.5  ...  0.76  0.65         0.78       1.56  4.0   0.65  0.30
# 3  7.15  30.8  ...  0.13  0.41         0.92       0.71  1.0   0.18  0.20
# 4  26.9  25.8  ...  0.97  1.00         0.42       0.58  3.0   0.15  0.30
#
#    CalPAC  CalKMnO4  CalACD
# 0   20000      4160    5200
# 1    4000      1600    1600
# 2   32000      5200    2400
# 3    8000      1440    1600
# 4   24000      1200    2400
#
# [5 rows x 26 columns]

# %%
data_Colour.head()
# Out:
#          Date  Raw_Colour  Raw_Turbidity  Raw_Ec  Raw_TDS  Raw_Ph    T1A  \
# 0   12/3/2019       500.0           74.7   118.4    64.60    7.32  420.0
# 1   12/4/2019       484.0           46.7   123.8    67.87    8.51  409.0
# 2  11/28/2019       326.0           42.1   169.5    78.30    7.43  101.0
# 3  11/29/2019       454.0           43.4   124.5    68.10    7.16   21.0
# 4  11/26/2019       307.0           38.3   118.4    86.32    7.09  124.0
#
#      T1B    T2A    T2B  ...  F2A   F2B  contact_tank  clear_well  PAC  KMnO4  \
# 0  155.0  500.0  500.0  ...  0.0   2.0             0           0  2.5   0.52
# 1  285.0  185.0  158.0  ...  0.0   0.0             0           0  0.5   0.20
# 2   90.0   85.0   72.0  ...  2.0   3.0             9          10  4.0   0.65
# 3   46.0   64.0   39.0  ...  4.0  10.0             8          10  1.0   0.18
# 4  249.0  153.0  210.0  ...  0.0   0.0            11          13  3.0   0.15
#
#     ACD  CalPAC  CalKMnO4  CalACD
# 0  0.65   20000      4160    5200
# 1  0.20    4000      1600    1600
# 2  0.30   32000      5200    2400
# 3  0.20    8000      1440    1600
# 4  0.30   24000      1200    2400
#
# [5 rows x 26 columns]

# %%
X_ph = data_PH[['CalPAC', 'CalKMnO4', 'Raw_Ph', 'CalACD','Raw_Colour','Raw_Turbidity','Raw_Ec','Raw_TDS']]
y_ph = data_PH['clear_well']
X_ec = data_EC[['CalPAC', 'CalKMnO4', 'Raw_Ph', 'CalACD','Raw_Colour','Raw_Turbidity','Raw_Ec','Raw_TDS']]
y_ec = data_EC['clear_well']
X_turbidity = data_Turbidity[['CalPAC', 'CalKMnO4', 'Raw_Ph', 'CalACD','Raw_Colour','Raw_Turbidity','Raw_Ec','Raw_TDS']]
y_turbidity = data_Turbidity['clear_well']
X_colour = data_Colour[['CalPAC', 'CalKMnO4', 'Raw_Ph', 'CalACD','Raw_Colour','Raw_Turbidity','Raw_Ec','Raw_TDS']]
y_colour = data_Colour['clear_well']
X_tds = data_TDS[['CalPAC', 'CalKMnO4', 'Raw_Ph', 'CalACD','Raw_Colour','Raw_Turbidity','Raw_Ec','Raw_TDS']]
y_tds = data_TDS['clear_well']

# %% [markdown]
# TDS

# %%
X_tds_train, X_tds_test, y_tds_train, y_tds_test = train_test_split(X_tds, y_tds, test_size=0.2, random_state=42)

# %%
X_tds_train, X_tds_test, y_tds_train, y_tds_test = train_test_split(X_tds, y_tds, test_size=0.2, random_state=42)

# Replace NGBoost with Decision Tree Regressor
model_tds = DecisionTreeRegressor(random_state=42)
model_tds.fit(X_tds_train, y_tds_train)

# Predict
y_tds_pred = model_tds.predict(X_tds_test)

# Results DataFrame
results_TDS = pd.DataFrame({
    'Actual': y_tds_test,
    'Predicted': y_tds_pred
})

# Plot Actual vs Predicted
plt.figure(figsize=(10, 6))
plt.scatter(results_TDS['Actual'], results_TDS['Predicted'], color='blue', alpha=0.7, label='Predictions')
min_val = min(results_TDS['Actual'].min(), results_TDS['Predicted'].min())
max_val = max(results_TDS['Actual'].max(), results_TDS['Predicted'].max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Ideal Fit (y=x)')
plt.title('Actual vs Predicted - TDS (Decision Tree)')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# pH

# %%
# Train the Decision Tree Regressor
model_ph = DecisionTreeRegressor(random_state=42)
model_ph.fit(X_ph_train, y_ph_train)

# Predict
y_ph_pred = model_ph.predict(X_ph_test)

# Plotting
results_PH = pd.DataFrame({
    'Actual': y_ph_test,
    'Predicted': y_ph_pred
})

plt.figure(figsize=(10, 6))
plt.scatter(results_PH['Actual'], results_PH['Predicted'], color='blue', alpha=0.7, label='Predictions')
min_val = min(results_PH['Actual'].min(), results_PH['Predicted'].min())
max_val = max(results_PH['Actual'].max(), results_PH['Predicted'].max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Ideal Fit (y=x)')
plt.title('Actual vs Predicted - PH (Decision Tree)')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# EC

# %%
X_ec_train, X_ec_test, y_ec_train, y_ec_test = train_test_split(X_ec, y_ec, test_size=0.2, random_state=42)

# 3. Train Decision Tree model
model_ec = DecisionTreeRegressor(random_state=42)
model_ec.fit(X_ec_train, y_ec_train)

# 4. Predict
y_ec_pred = model_ec.predict(X_ec_test)

# 5. Plot
results_EC = pd.DataFrame({
    'Actual': y_ec_test,
    'Predicted': y_ec_pred
})

plt.figure(figsize=(10, 6))
plt.scatter(results_EC['Actual'], results_EC['Predicted'], color='blue', alpha=0.7, label='Predictions')
min_val = min(results_EC['Actual'].min(), results_EC['Predicted'].min())
max_val = max(results_EC['Actual'].max(), results_EC['Predicted'].max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Ideal Fit (y=x)')
plt.title('Actual vs Predicted - EC (Decision Tree)')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Turbidity

# %%
X_turbidity_train, X_turbidity_test, y_turbidity_train, y_turbidity_test = train_test_split(
    X_turbidity, y_turbidity, test_size=0.2, random_state=42
)

# Create and train the Decision Tree model
model_turbidity = DecisionTreeRegressor(random_state=42)
model_turbidity.fit(X_turbidity_train, y_turbidity_train)

# Predict
y_turbidity_pred = model_turbidity.predict(X_turbidity_test)

# Create a results DataFrame
results_TURBIDITY = pd.DataFrame({
    'Actual': y_turbidity_test,
    'Predicted': y_turbidity_pred
})

# Plot the actual vs predicted
plt.figure(figsize=(10, 6))
plt.scatter(results_TURBIDITY['Actual'], results_TURBIDITY['Predicted'], color='blue', alpha=0.7, label='Predictions')
min_val = min(results_TURBIDITY['Actual'].min(), results_TURBIDITY['Predicted'].min())
max_val = max(results_TURBIDITY['Actual'].max(), results_TURBIDITY['Predicted'].max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Ideal Fit (y=x)')
plt.title('Actual vs Predicted - Turbidity (Decision Tree)')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Colour

# %%
X_colour_train, X_colour_test, y_colour_train, y_colour_test = train_test_split(
    X_colour, y_colour, test_size=0.2, random_state=42
)

# Train the Decision Tree model
model_colour = DecisionTreeRegressor(random_state=42)
model_colour.fit(X_colour_train, y_colour_train)

# Predict
y_colour_pred = model_colour.predict(X_colour_test)

# Create DataFrame of results
results_COLOUR = pd.DataFrame({
    'Actual': y_colour_test,
    'Predicted': y_colour_pred
})

# Plot Actual vs Predicted
plt.figure(figsize=(10, 6))
plt.scatter(results_COLOUR['Actual'], results_COLOUR['Predicted'], color='blue', alpha=0.7, label='Predictions')
min_val = min(results_COLOUR['Actual'].min(), results_COLOUR['Predicted'].min())
max_val = max(results_COLOUR['Actual'].max(), results_COLOUR['Predicted'].max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Ideal Fit (y=x)')
plt.title('Actual vs Predicted - Colour (Decision Tree)')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_model(y_test, y_pred, target_name):
    r2 = r2_score(y_test, y_pred)
    accuracy = r2 * 100  # Convert R² to percentage
    print(f"\nEvaluation Metrics for {target_name}:")
    print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred):.2f}")
    print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred):.2f}")
    print(f"R-squared (R²): {r2:.2f}")


evaluate_model(y_turbidity_test, y_turbidity_pred, "Turbidity")
evaluate_model(y_ec_test, y_ec_pred, "EC")
evaluate_model(y_tds_test, y_tds_pred, "TDS")
evaluate_model(y_ph_test, y_ph_pred, "PH")
evaluate_model(y_colour_test, y_colour_pred, "Colour")
# Out:
# Evaluation Metrics for Turbidity:
# Mean Absolute Error (MAE): 1.43
# Mean Squared Error (MSE): 24.02
# R-squared (R²): -0.16
#
# Evaluation Metrics for EC:
# Mean Absolute Error (MAE): 32.69
# Mean Squared Error (MSE): 2001.22
# R-squared (R²): -0.89
#
# Evaluation Metrics for TDS:
# Mean Absolute Error (MAE): 30.17
# Mean Squared Error (MSE): 11288.61
# R-squared (R²): -0.55
#
# Evaluation Metrics for PH:
# Mean Absolute Error (MAE): 0.38
# Mean Squared Error (MSE): 0.25
# R-squared (R²): -0.91
#
# Evaluation Metrics for Colour:
# Mean Absolute Error (MAE): 8.78
# Mean Squared Error (MSE): 545.79
# R-squared (R²): -6.48
